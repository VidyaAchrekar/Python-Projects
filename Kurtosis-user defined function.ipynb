# %%
list1=[13,14,15,16,18,19,20,20,21,22,22,23,24,24,24,24,26,26,26,26]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # user defined function

# %%
def skewness_kurtosis(list1):
    import math
    mean=sum(list1)/len(list1)
    new_list=[]
    new_list1=[]
    new_list2=[]
    for i in list1:
        k=(i-mean)**2
        new_list.append(k)
    std=math.sqrt(sum(new_list)/len(new_list))
    for j in list1:
        j=((j-mean)/std)**3
        new_list1.append(j)
    skew=sum(new_list1)/len(new_list1)
    for z in list1:
        z=((z-mean)/std)**4
        new_list2.append(z)
    absolute_kurtosis=sum(new_list2)/len(new_list2)
    relative_kurtosis=(absolute_kurtosis-3)
    return ('standard deviation value:',std,'skewness value:',skew,'Absolute kurtosis value:',absolute_kurtosis,'Relative kurtosis value:',relative_kurtosis)

# %%
skewness_kurtosis(list1)
# Out:
# ('standard deviation value:',
#  4.065402809070708,
#  'skewness value:',
#  -0.5683913217999862,
#  'Absolute kurtosis value:',
#  2.1549146613063415,
#  'Relative kurtosis value:',
#  -0.8450853386936585)

# %%
from scipy.stats import kurtosis
kurt=kurtosis(list1)
print('relative kurtosis value:',kurt)
# Out:
# relative kurtosis value: -0.8450853386936585

# %%
from scipy.stats import skew
skew=skew(list1)
skew
# Out:
# -0.5683913217999861

# %% [markdown]
# * Exercise 1:
# * list1=[12,15,100,250,70,100,500,367,387,469,400,450,650,700,490,
#          359,800,880,850,900,940,960,875,467,1000]
# * calculate Variance,Skewness,kurtosis
# * Draw distribution plots

# %%
list2=[12,15,100,250,70,100,500,367,387,469,400,450,650,700,490,
   359,800,880,850,900,940,960,875,467,1000]

# %%
skewness_kurtosis(list2)
# Out:
# ('standard deviation value:',
#  314.4099082408186,
#  'skewness value:',
#  -0.06003142089021784,
#  'Absolute kurtosis value:',
#  1.7865396652597298,
#  'Relative kurtosis value:',
#  -1.2134603347402702)

# %%
from scipy.stats import skew
skew(list2)
# Out:
# -0.06003142089021768

# %%
from scipy.stats import kurtosis
kurtosis(list2)
# Out:
# -1.213460334740271

# %%
import seaborn as sns
sns.distplot(list2)
# Out:
# Unable to revert mtime: /Library/Fonts
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# /Users/vidyaanvekar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# * Exercise 2:
# * list1=[500,580,600,640,690,700,720,750,770,800,879,987,
#        945,1000,1200,1234,2345,2000,3500,3460,4000]
# * calculate Variance,Skewness,kurtosis
# * Draw distribution plots

# %%
list3=[500,580,600,640,690,700,720,750,770,800,879,987,
 945,1000,1200,1234,2345,2000,3500,3460,4000]
skewness_kurtosis(list3)
# Out:
# ('standard deviation value:',
#  1042.4672417459356,
#  'skewness value:',
#  1.5072292269203336,
#  'Absolute kurtosis value:',
#  3.806980751454661,
#  'Relative kurtosis value:',
#  0.806980751454661)

# %%
from scipy.stats import skew
skew(list3)
# Out:
# 1.5072292269203338

# %%
from scipy.stats import kurtosis
kurtosis(list3)
# Out:
# 0.8069807514546614

# %%
sns.distplot(list3)
# Out:
# /Users/vidyaanvekar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
